# %% [markdown]
# ## Scenario 1: A single data scientist participating in an ML competition
#
# MLflow setup:
# * Tracking server: no
# * Backend store: local filesystem
# * Artifacts store: local filesystem
#
# The experiments can be explored locally by launching the MLflow UI.

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\trinh\\Desktop\\Projet\\02-tracking\\scenario'

# %%
import mlflow

# %%
print(f"tracking URI: '{mlflow.get_tracking_uri()}'")
# Out:
# tracking URI: 'sqlite:///mlflow.db'

# %%
mlflow.search_experiments()
# Out:
# 2025/12/09 15:29:49 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2025/12/09 15:29:49 INFO mlflow.store.db.utils: Updating database tables
# 2025/12/09 15:29:49 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# 2025/12/09 15:29:49 INFO alembic.runtime.migration: Will assume non-transactional DDL.
# 2025/12/09 15:29:49 INFO alembic.runtime.migration: Running upgrade  -> 451aebb31d03, add metric step
# 2025/12/09 15:29:49 INFO alembic.runtime.migration: Running upgrade 451aebb31d03 -> 90e64c465722, migrate user column to tags
# 2025/12/09 15:29:49 INFO alembic.runtime.migration: Running upgrade 90e64c465722 -> 181f10493468, allow nulls for metric values
# 2025/12/09 15:29:49 INFO alembic.runtime.migration: Running upgrade 181f10493468 -> df50e92ffc5e, Add Experiment Tags Table
# 2025/12/09 15:29:49 INFO alembic.runtime.migration: Running upgrade df50e92ffc5e -> 7ac759974ad8, Update run tags with larger limit
# 2025/12/09 15:29:49 INFO alembic.runtime.migration: Running upgrade 7ac759974ad8 -> 89d4b8295536, create latest metrics table
# 2025/12/09 15:29:49 INFO alembic.runtime.migration: Running upgrade 89d4b8295536 -> 2b4d017a5e9b, add model registry tables to db
# 2025/12/09 15:29:49 INFO alembic.runtime.migration: Running upgrade 2b4d017a5e9b -> cfd24bdc0731, Update run status constraint with killed
# 2025/12/09 15:29:49 INFO alembic.runtime.migration: Running upgrade cfd24bdc0731 -> 0a8213491aaa, drop_duplicate_killed_constraint
# 2025/12/09 15:29:49 INFO alembic.runtime.migration: Running upgrade 0a8213491aaa -> 728d730b5ebd, add registered model tags table
# 2025/12/09 15:29:49 INFO alembic.runtime.migration: Running upgrade 728d730b5ebd -> 27a6a02d2cf1, add model version tags table
# 2025/12/09 15:29:49 INFO alembic.runtime.migration: Running upgrade 27a6a02d2cf1 -> 84291f40a231, add run_link to model_version
# 2025/12/09 15:29:49 INFO alembic.runtime.migration: Running upgrade 84291f40a231 -> a8c4a736bde6, allow nulls for run_id
# 2025/12/09 15:29:50 INFO alembic.runtime.migration: Running upgrade a8c4a736bde6 -> 39d1c3be5f05, add_is_nan_constraint_for_metrics_tables_if_necessary
# 2025/12/09 15:29:50 INFO alembic.runtime.migration: Running upgrade 39d1c3be5f05 -> c48cb773bb87, reset_default_value_for_is_nan_in_metrics_table_for_mysql
# 2025/12/09 15:29:50 INFO alembic.runtime.migration: Running upgrade c48cb773bb87 -> bd07f7e963c5, create index on run_uuid
# 2025/12/09 15:29:50 INFO alembic.runtime.migration: Running upgrade bd07f7e963c5 -> 0c779009ac13, add deleted_time field to runs table
# 2025/12/09 15:29:50 INFO alembic.runtime.migration: Running upgrade 0c779009ac13 -> cc1f77228345, change param value length to 500
# 2025/12/09 15:29:50 INFO alembic.runtime.migration: Running upgrade cc1f77228345 -> 97727af70f4d, Add creation_time and last_update_time to experiments table
# 2025/12/09 15:29:50 INFO alembic.runtime.migration: Running upgrade 97727af70f4d -> 3500859a5d39, Add Model Aliases table
# 2025/12/09 15:29:50 INFO alembic.runtime.migration: Running upgrade 3500859a5d39 -> 7f2a7d5fae7d, add datasets inputs input_tags tables
# 2025/12/09 15:29:50 INFO alembic.runtime.migration: Running upgrade 7f2a7d5fae7d -> 2d6e25af4d3e, increase max param val length from 500 to 8000
# 2025/12/09 15:29:50 INFO alembic.runtime.migration: Running upgrade 2d6e25af4d3e -> acf3f17fdcc7, add storage location field to model versions
# 2025/12/09 15:29:50 INFO alembic.runtime.migration: Running upgrade acf3f17fdcc7 -> 867495a8f9d4, add trace tables
# 2025/12/09 15:29:50 INFO alembic.runtime.migration: Running upgrade 867495a8f9d4 -> 5b0e9adcef9c, add cascade deletion to trace tables foreign keys
# 2025/12/09 15:29:50 INFO alembic.runtime.migration: Running upgrade 5b0e9adcef9c -> 4465047574b1, increase max dataset schema size
# 2025/12/09 15:29:50 INFO alembic.runtime.migration: Running upgrade 4465047574b1 -> f5a4f2784254, increase run tag value limit to 8000
# 2025/12/09 15:29:50 INFO alembic.runtime.migration: Running upgrade f5a4f2784254 -> 0584bdc529eb, add cascading deletion to datasets from experiments
# 2025/12/09 15:29:50 INFO alembic.runtime.migration: Running upgrade 0584bdc529eb -> 400f98739977, add logged model tables
# 2025/12/09 15:29:50 INFO alembic.runtime.migration: Running upgrade 400f98739977 -> 6953534de441, add step to inputs table
# 2025/12/09 15:29:50 INFO alembic.runtime.migration: Running upgrade 6953534de441 -> bda7b8c39065, increase_model_version_tag_value_limit
# 2025/12/09 15:29:50 INFO alembic.runtime.migration: Running upgrade bda7b8c39065 -> cbc13b556ace, add V3 trace schema columns
# 2025/12/09 15:29:50 INFO alembic.runtime.migration: Running upgrade cbc13b556ace -> 770bee3ae1dd, add assessments table
# 2025/12/09 15:29:50 INFO alembic.runtime.migration: Running upgrade 770bee3ae1dd -> a1b2c3d4e5f6, add spans table
# 2025/12/09 15:29:50 INFO alembic.runtime.migration: Running upgrade a1b2c3d4e5f6 -> de4033877273, create entity_associations table
# 2025/12/09 15:29:50 INFO alembic.runtime.migration: Running upgrade de4033877273 -> 1a0cddfcaa16, Add webhooks and webhook_events tables
# 2025/12/09 15:29:50 INFO alembic.runtime.migration: Running upgrade 1a0cddfcaa16 -> 534353b11cbc, add scorer tables
# 2025/12/09 15:29:50 INFO alembic.runtime.migration: Running upgrade 534353b11cbc -> 71994744cf8e, add evaluation datasets
# 2025/12/09 15:29:50 INFO alembic.runtime.migration: Running upgrade 71994744cf8e -> 3da73c924c2f, add outputs to dataset record
# 2025/12/09 15:29:50 INFO alembic.runtime.migration: Running upgrade 3da73c924c2f -> bf29a5ff90ea, add jobs table
# 2025/12/09 15:29:50 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# 2025/12/09 15:29:50 INFO alembic.runtime.migration: Will assume non-transactional DDL.
# [<Experiment: artifact_location='file:c:/Users/trinh/Desktop/Projet/02-tracking/scenario/mlruns/0', creation_time=1765290590896, experiment_id='0', last_update_time=1765290590896, lifecycle_stage='active', name='Default', tags={}>]

# %% [markdown]
# ### Creating an experiment and logging a new run

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import load_iris
from sklearn.metrics import accuracy_score

mlflow.set_experiment("my-experiment-1")

with mlflow.start_run():

    X, y = load_iris(return_X_y=True)

    params = {"C": 0.1, "random_state": 42}
    mlflow.log_params(params)

    lr = LogisticRegression(**params).fit(X, y)
    y_pred = lr.predict(X)
    mlflow.log_metric("accuracy", accuracy_score(y, y_pred))

    mlflow.sklearn.log_model(lr, artifact_path="models")
    print(f"default artifacts URI: '{mlflow.get_artifact_uri()}'")
# Out:
# 2025/12/09 15:12:13 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# default artifacts URI: 'file:c:/Users/trinh/Desktop/Projet/02-tracking/scenario/mlruns/1/2696601fe36440d99792bec45f7a4aa6/artifacts'

# %%
mlflow.search_experiments()
# Out:
# [<Experiment: artifact_location='file:c:/Users/trinh/Desktop/Projet/02-tracking/scenario/mlruns/1', creation_time=1765289446358, experiment_id='1', last_update_time=1765289446358, lifecycle_stage='active', name='my-experiment-1', tags={}>,
#  <Experiment: artifact_location='file:c:/Users/trinh/Desktop/Projet/02-tracking/scenario/mlruns/0', creation_time=1765289375876, experiment_id='0', last_update_time=1765289375876, lifecycle_stage='active', name='Default', tags={}>]

# %% [markdown]
# ### Interacting with the model registry

# %%
from mlflow.tracking import MlflowClient


client = MlflowClient()

# %%
from mlflow.exceptions import MlflowException

try:
    client.search_registered_models()
except MlflowException:
    print("It's not possible to access the model registry :(")
# Out:
# 2025/12/09 15:13:19 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2025/12/09 15:13:19 INFO mlflow.store.db.utils: Updating database tables
# 2025/12/09 15:13:19 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# 2025/12/09 15:13:19 INFO alembic.runtime.migration: Will assume non-transactional DDL.
